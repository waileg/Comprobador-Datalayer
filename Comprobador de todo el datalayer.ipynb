# %%
#pip install beautifulsoup4

# %%
#pip install selenium

# %%
#pip install requests

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
# url= "https://estudiar.universidadeuropea.com/animacion-diseno-videojuegos/"
#
# def comprobador(url):
#     response = requests.get(url)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     datalayer_script = soup.find('script', {'data-name': 'dataLayer'})
#     datalayer_script=soup.find_all("script")
#
#     if datalayer_script:
#         datalayer_content = str(datalayer_script)
#
#         # Verifica si el campo personalizado existe en el datalayer
#         custom_field = 'academicType'
#         if custom_field in datalayer_content:
#             print(f"Si está el campo personalizado para la URL '{url}'")
#         else:
#             print(f"No está el campo personalizado para la URL '{url}'")
#     else:
#         print("No se encontró el script del datalayer de GTM en la página.")

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
bbdd=pd.read_csv("/Users/9140/Desktop/Comprobador_dummy.csv",sep=";")
bbdd=pd.DataFrame(bbdd)
bbdd
# Out:
#   Fecha de entrega Fecha petición            Título de la LP Tipo LP      BU  \
# 0       26/10/2021     antes 2022    Animacion y videojuegos    Área  Madrid
# 1       16/12/2021     antes 2022  Landing área Arquitectura    Área  Madrid
#
#     Modalidad  Campus Tipo de programa    País   Idioma  ...    Modality  \
# 0  Presencial  Varios            Grado  España  Español  ...  presencial
# 1  Presencial  Varios           Varios  España  Español  ...         NaN
#
#     name academicprice productid recognition                         School  \
# 0  todos       20000.0     todos    official  universidad europea de madrid
# 1    NaN           NaN       NaN         NaN                            NaN
#
#         start           academictype    hierarchy  language
# 0  20230918.0  grados universitarios  landingpage   espanol
# 1         NaN                    NaN          NaN       NaN
#
# [2 rows x 30 columns]

# %%
def revisión(field,cu):
    if field:
        datalayer_content = str(field)
        academicType_o='academicType'
        academicArea_o='academiArea'
        academicCampus_o='academicCampus'
        academicDepartment_o='academicDepartment'
        academicDuration_o='academicDuration'
        academicECTs_o='academicECTs'
        academicExpedite_o='academicExpedite'
        academicLanguage_o='academicLanguage'
        academicMethodology_o='academicMethodology'
        academicModality_o='academicModality'
        academicName_o='academicName'
        academicPrice_o='academicPrice'
        academicProductID_o='academicProductID'
        academicRecognition_o='academicRecognition'
        academicSchool_o='academicSchool'
        academicStart_o='academicStart'
        pageHierarchy_o='pageHierarchy'
        pageLanguage_o='pageLanguage'

        contador=0
        #1
        if academicType_o in datalayer_content:
            if academicType==Variable1:
                print("Check Type")
            elif academicType != Variable1:
                print("Revisar Type")    
        else:
            print("No se encuentra academicType en el datalayer")
            
        contador=contador+1
        #2    
        if academicArea_o in datalayer_content:
            if academicType==Variable1:
                print("Check Área")
            elif academicType != Variable1:
                print("Revisar Área")
        else:
            print("No se encuentra academicArea en el datalayer")
         #3  
        contador=contador+1
        if academicCampus_o in datalayer_content:
            if academicType==Variable1:
                print("Check Campus")
            elif academicType != Variable1:
                print("Revisar Campus")
        else:
            print("No se encuentra academicCampus en el datalayer")
         #4  
        contador=contador+1
        if academicDepartment_o in datalayer_content:
            if academicType==Variable1:
                print("Check Department")
            elif academicType != Variable1:
                print("Revisar Department")
        else:
            print("No se encuentra academicDepartment en el datalayer")
         #5 
        contador=contador+1
        if academicDuration_o in datalayer_content:
            if academicType==Variable1:
                print("Check Duration")
            elif academicType != Variable1:
                print("Revisar Duration")
        else:
            print("No se encuentra academicDuration en el datalayer")

         #6 
        contador=contador+1
        if academicECTs_o in datalayer_content:
            if academicType==Variable1:
                print("Check ECTs")
            elif academicType != Variable1:
                print("Revisar ECTs")
        else:
            print("No se encuentra academicECTs en el datalayer")
         #7  
        contador=contador+1
        if academicExpedite_o in datalayer_content:
            if academicType==Variable1:
                print("Check Expedite")
            elif academicType != Variable1:
                print("Revisar Expedite")
        else:
            print("No se encuentra academicExpedite en el datalayer")
         #8  
        contador=contador+1
        if academicLanguage_o in datalayer_content:
            if academicType==Variable1:
                print("Check Language")
            elif academicType != Variable1:
                print("Revisar Language")
        else:
            print("No se encuentra academicLanguage en el datalayer")
         #9  
        contador=contador+1
        if academicMethodology_o in datalayer_content:
            if academicType==Variable1:
                print("Check Methodology")
            elif academicType != Variable1:
                print("Revisar Methodology")
        else:
            print("No se encuentra academicMethodology en el datalayer")
         #10 
        contador=contador+1
        if academicModality_o in datalayer_content:
            if academicType==Variable1:
                print("Check Modality")
            elif academicType != Variable1:
                print("Revisar Modality")
        else:
            print("No se encuentra academicModality en el datalayer")
         #11  
        contador=contador+1
        if academicName_o in datalayer_content:
            if academicType==Variable1:
                print("Check Name")
            elif academicType != Variable1:
                print("Revisar Name")
        else:
            print("No se encuentra academicName en el datalayer")
         #12
        contador=contador+1
        if academicPrice_o in datalayer_content:
            if academicType==Variable1:
                print("Check Price")
            elif academicType != Variable1:
                print("Revisar Price")
        else:
            print("No se encuentra academicPrice en el datalayer")
         #13
        contador=contador+1
        if academicProductID_o in datalayer_content:
            if academicType==Variable1:
                print("Check ProductID")
            elif academicType != Variable1:
                print("Revisar ProductID")
        else:
            print("No se encuentra academicProductID en el datalayer")
         #14  
        contador=contador+1
        if academicRecognition_o in datalayer_content:
            if academicType==Variable1:
                print("Check Recognition")
            elif academicType != Variable1:
                print("Revisar Recognition")
        else:
            print("No se encuentra academicRecognition en el datalayer")
         #15
        contador=contador+1
        if academicSchool_o in datalayer_content:
            if academicType==Variable1:
                print("Check academicSchool")
            elif academicType != Variable1:
                print("Revisar academicSchool")
        else:
            print("No se encuentra academicSchool en el datalayer")
         #16  
        contador=contador+1
        if academicStart_o in datalayer_content:
            if academicType==Variable1:
                print("Check academicStart")
            elif academicType != Variable1:
                print("Revisar academicStart")
        else:
            print("No se encuentra academicStart en el datalayer")
         #17  
        contador=contador+1
        if pageHierarchy_o in datalayer_content:
            if academicType==Variable1:
                print("Check pageHierarchy")
            elif academicType != Variable1:
                print("Revisar pageHierarchy")
        else:
            print("No se encuentra pageHierarchy en el datalayer")
            
        #18  
        contador=contador+1
        if pageLanguage_o in datalayer_content:
            if academicType==Variable1:
                print("Check Lenguage")
            elif academicType != Variable1:
                print("Revisar Lenguage")
        else:
            print("No se encuentra pageLanguage en el datalayer")
         
        contador=contador+1
        
        if contador == 18:
            print("Todas las variables analizadas.")
        else:
            print("Alguna variable no fué analizada.")

# %%
def comprobador(url,cu):
    print(url)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    datalayer_script = soup.find('script', {'data-name': 'dataLayer'})
    datalayer_script=soup.find_all("script")
    utilidad=pd.read_csv("/Users/9140/Desktop/Comprobador_dummy.csv",sep=";")
    utilidad=pd.DataFrame(utilidad)
    revisión(datalayer_script,cu)

# %%
df=[("","")]
df=pd.DataFrame(df,columns=["Variable_dada","Variable_recibida"],index=['academicType'
,'academiArea','academicCampus','academicDepartment','academicDuration','academicECTs','academicExpedite',                                                                                         
'academicLanguage','academicMethodology','academicModality','academicName','academicPrice','academicProductID',
'academicRecognition','academicSchool','academicStart','pageHierarchy','pageLanguage'])

# %%
df
# Out:
#                     Variable_dada Variable_recibida
# academicType
# academiArea
# academicCampus
# academicDepartment
# academicDuration
# academicECTs
# academicExpedite
# academicLanguage
# academicMethodology
# academicModality
# academicName
# academicPrice
# academicProductID
# academicRecognition
# academicSchool
# academicStart
# pageHierarchy
# pageLanguage

# %%
for i, row in df.iterrows():
    # Obtener el índice correspondiente a la fila actual
    index = df.index[i]
    
    # Obtener el valor de la primera columna del archivo CSV
    value = row[0]
    
    # Actualizar el dataframe con el valor correspondiente
    df.at[index, 'Variable_dada'] = value

# Mostrar el dataframe resultante
print(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 3
#       1 for i, row in df.iterrows():
#       2     # Obtener el índice correspondiente a la fila actual
# ----> 3     index = df.index[i]
#       5     # Obtener el valor de la primera columna del archivo CSV
#       6     value = row[0]
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5339, in Index.__getitem__(self, key)
#    5336     else:
#    5337         key = np.asarray(key, dtype=bool)
# -> 5339 result = getitem(key)
#    5340 # Because we ruled out integer above, we always get an arraylike here
#    5341 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import pandas as pd

# Definir el dataframe inicial
df = [("","")]
df = pd.DataFrame(df, columns=["Variable_dada","Variable_recibida"], index=[
    'academicType', 'academiArea', 'academicCampus', 'academicDepartment',
    'academicDuration', 'academicECTs', 'academicExpedite',
    'academicLanguage', 'academicMethodology', 'academicModality',
    'academicName', 'academicPrice', 'academicProductID',
    'academicRecognition', 'academicSchool', 'academicStart',
    'pageHierarchy', 'pageLanguage'])

# Leer el archivo CSV
data = pd.read_csv('archivo.csv')

# Iterar sobre las filas del archivo CSV
for i, row in data.iterrows():
    # Obtener el índice correspondiente a la fila actual
    index = df.index[i]
    
    # Obtener el valor de la primera columna del archivo CSV
    value = row[0]
    
    # Actualizar el dataframe con el valor correspondiente
    df.at[index, 'Variable_dada'] = value

# Mostrar el dataframe resultante
print(df)

# %%
df.iloc[0,0]
# Out:
# 'villaviciosa de odon y creative campus (madrid)'

# %%
bbdd.iloc[0,12]
# Out:
# 'todas'

# %%
cu=2
for a in bbdd["URL Wagtail"]:
    print(a)


    #comprobador(a,cu)
# Out:
# https://estudiar.universidadeuropea.com/animacion-diseno-videojuegos/
# https://estudiar.universidadeuropea.com/area-arquitectura/

# %%
bbdd.columns
# Out:
# Index(['Fecha de entrega', 'Fecha petición', 'Título de la LP', 'Tipo LP',
#        'BU', 'Modalidad', 'Campus', 'Tipo de programa', 'País', 'Idioma', 'PM',
#        'URL Wagtail', 'AcademicArea', 'Campus.1', 'Department', 'Duration',
#        'ECTs', 'Expedite', 'Language', 'Methodology', 'Modality', 'name',
#        'academicprice', 'productid', 'recognition', 'School', 'start',
#        'academictype', 'hierarchy', 'language'],
#       dtype='object')
